# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
from categories import store_categories
import random
import numpy as np
import seaborn as sns
from dashboard import get_df_ready
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
# %run scraper.py
from scraper import BankScraper

with open("../secure/username") as file:
    username = file.read()

with open("../secure/password") as file:
    password = file.read()

scraper = BankScraper()
scraper.login(username, password)
df = scraper.getAccountTransactions()
scraper.logout()
df.to_csv('secure/scraped_transactions.csv')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\gmspr\Documents\School\Senior\Fall 2023\STAT 386\project\personal-budget-tool\scraper\scraping.ipynb Cell 2 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/gmspr/Documents/School/Senior/Fall%202023/STAT%20386/project/personal-budget-tool/scraper/scraping.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> get_ipython().run_line_magic('run', 'scraper.py')
#       <a href='vscode-notebook-cell:/c%3A/Users/gmspr/Documents/School/Senior/Fall%202023/STAT%20386/project/personal-budget-tool/scraper/scraping.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> from scraper import BankScraper
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gmspr/Documents/School/Senior/Fall%202023/STAT%20386/project/personal-budget-tool/scraper/scraping.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> with open("../../secure/username") as file:
#       <a href='vscode-notebook-cell:/c%3A/Users/gmspr/Documents/School/Senior/Fall%202023/STAT%20386/project/personal-budget-tool/scraper/scraping.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>     username = file.read()
#       <a href='vscode-notebook-cell:/c%3A/Users/gmspr/Documents/School/Senior/Fall%202023/STAT%20386/project/personal-budget-tool/scraper/scraping.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> with open("../../secure/password") as file:
#
# File c:\Users\gmspr\anaconda3\envs\stat386\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../secure/username'

# %%
df.to_csv('secure/scraped_transactions.csv')

# %%
def make_dummy_data():
    dummy = pd.DataFrame()
    dummy['date'] = pd.date_range('2023-09-01', '2023-10-31')
    descriptions = []
    categories = []
    costs = []
    for _ in range(len(dummy)):
        store, category = random.choice(list(store_categories.items()))
        descriptions.append(store)
        categories.append(category)
        costs.append(round(np.random.gamma(.5, 100, size = 1)[0], 2))
    
    dummy['description'] = descriptions
    dummy['category'] = categories
    dummy['amount'] = costs
    dummy['account'] = 'Credit Card'
    dummy['balance'] = round(dummy['amount'].cumsum(),2)
    dummy.sort_values(by='date', ascending=False, inplace=True)
    dummy.to_csv('dummy_data.csv')

# %%
make_dummy_data()

# %%
df = pd.read_csv('dummy_data.csv', index_col=0,  parse_dates=['date'])
df
# Out:
#          date            description         category  amount      account  \
# 60 2023-10-31         WM SUPERCENTER        Groceries   66.36  Credit Card
# 59 2023-10-30                LAZ PKG          Parking    4.77  Credit Card
# 58 2023-10-29          UTAH FIRST CU      Car Payment   15.78  Credit Card
# 57 2023-10-28       UTAH DMV OFFICES              Car    0.80  Credit Card
# 56 2023-10-27  SALT & STRAW ICE CREA  Food - Desserts   45.14  Credit Card
# ..        ...                    ...              ...     ...          ...
# 4  2023-09-05           AMERICAN AIR          Airline    6.93  Credit Card
# 3  2023-09-04       UTAH DMV OFFICES              Car   63.12  Credit Card
# 2  2023-09-03   PROVO CITY UTILI DES        Utilities  156.54  Credit Card
# 1  2023-09-02            SMITHS FUEL              Gas   24.74  Credit Card
# 0  2023-09-01              BYU STORE         Shopping    1.50  Credit Card
#
#     balance
# 60  2371.58
# 59  2305.22
# 58  2300.45
# 57  2284.67
# 56  2283.87
# ..      ...
# 4    252.83
# 3    245.90
# 2    182.78
# 1     26.24
# 0      1.50
#
# [61 rows x 6 columns]
